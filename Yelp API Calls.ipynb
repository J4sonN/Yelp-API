# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# # Load Credentials and Create Yelp API objects

# %%
with open(r"C:\Users\black\.secret\yelp_api.json") as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
yelp =  YelpAPI(login['api-key'], timeout_s = 5.0)

# %%
location = 'Santa Ana, CA 92703'
term = 'pho'

# %%
location.split(',')[0]
# Out:
# 'Santa Ana'

# %%
## Specify fodler for saving data
Folder = 'Data/'

os.makedirs(Folder, exist_ok = True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = Folder+f"{location.split(',')[0]}-{term}.json"

# %% [markdown]
# # Check if Json file exists and create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. saving empty list to file")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
        json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Santa Ana-pho.json already exists.

# %%
results = yelp.search_query(term = term, location = location)

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                    alias  \
# 0   svgFm8Ybzq9D8vPPhWE38A           pho-79-restaurant-garden-grove
# 1   I8aR6AojaY3w4bfiL5zacg                monstar-kitchen-santa-ana
# 2   FjzHELOnbk0oFBCEluBs7g                pho-nam-dinh-garden-grove
# 3   dItF3E6UqrS_MjmiFaaLfQ                  pho-flavor-garden-grove
# 4   TT0Y5sxPE2R5l0Pv_VxbNQ                   pho-redbo-garden-grove
# 5   jGlHGLneaPZ3vS5l0nRRXA              pho-kuroushi-garden-grove-2
# 6   fAptoiXJxRK7KqaNsBAKTg                   phoholic-westminster-2
# 7   7_lDdYuloowE2Jlav8PRnQ                      pho-45-garden-grove
# 8   t1wUKwUTUGaQzoAlxzVFGw                         mr-pho-anaheim-3
# 9   L9hK2pkuA-Pykty3cBw_Jg                    saigon-9-garden-grove
# 10  pRRjdTSeclWX7VEeN277vQ     pho-tau-bay-ltt-restaurant-santa-ana
# 11  3N80q1_B9b1gpUM8hia3vQ           khoi-restaurant-garden-grove-3
# 12  o-54PxRLT_teg18hwEmACg  99999-restaurant-phở-út-nô-garden-grove
# 13  EjuethqTHCA76eW43u7hpQ                   nguyens-kitchen-orange
# 14  vK-jtjE3cvO89juM-bVeHA    quán-bún-cô-giáo-thảo-garden-grove-12
# 15  m-holIZGAgiPB-TvKwv47Q               pho-ga-hai-van-westminster
# 16  mkdVf7AenwvlGXI6-N3pLw                    pho-101-westminster-2
# 17  jNcQrKfBf4cj23lZOgaXLw                  pho-318-fountain-valley
# 18  mcxIj_H58i3K_1sSLMHCCQ                    pho-thanh-westminster
# 19  SSiEJ5LxwSZoyJ75RZ0zWA                      pho-v-999-santa-ana
#
#                             name  \
# 0              Pho 79 Restaurant
# 1                Monstar Kitchen
# 2                   Pho Nam Dinh
# 3                     Pho Flavor
# 4                      Pho Redbo
# 5                   Pho Kuroushi
# 6                       PhoHolic
# 7                         Pho 45
# 8                         Mr Pho
# 9                       Saigon 9
# 10    Pho Tau Bay Ltt Restaurant
# 11               Khoi Restaurant
# 12  99999 Restaurant - Phở Út Nô
# 13              Nguyen's Kitchen
# 14        Quán Bún Cô Giáo Thảo
# 15                Pho Ga Hai Van
# 16                       Pho 101
# 17                       PHO 318
# 18                     Pho Thanh
# 19                     Pho V 999
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/y_SL4P...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/K5m1f8...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/WBrzet...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/Y8P-FH...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/BE9BsO...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/x6gPI4...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/dsdPDz...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/aYlDYm...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/4c8mea...      False
# 9   https://s3-media1.fl.yelpcdn.com/bphoto/tklMDC...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/YJIvNX...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/luxs98...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/tFP_Pd...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/lBs0Iv...      False
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/8wKZI2...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/0VXKK1...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/ktFLO6...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/Y6-H0_...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/Mib3HC...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/Xyoe9i...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/pho-79-restaurant-gar...          3100
# 1   https://www.yelp.com/biz/monstar-kitchen-santa...            39
# 2   https://www.yelp.com/biz/pho-nam-dinh-garden-g...           558
# 3   https://www.yelp.com/biz/pho-flavor-garden-gro...           347
# 4   https://www.yelp.com/biz/pho-redbo-garden-grov...           938
# 5   https://www.yelp.com/biz/pho-kuroushi-garden-g...           137
# 6   https://www.yelp.com/biz/phoholic-westminster-...          1447
# 7   https://www.yelp.com/biz/pho-45-garden-grove?a...          1852
# 8   https://www.yelp.com/biz/mr-pho-anaheim-3?adju...           721
# 9   https://www.yelp.com/biz/saigon-9-garden-grove...           405
# 10  https://www.yelp.com/biz/pho-tau-bay-ltt-resta...           328
# 11  https://www.yelp.com/biz/khoi-restaurant-garde...             9
# 12  https://www.yelp.com/biz/99999-restaurant-ph%E...            61
# 13  https://www.yelp.com/biz/nguyens-kitchen-orang...          2439
# 14  https://www.yelp.com/biz/qu%C3%A1n-b%C3%BAn-c%...           584
# 15  https://www.yelp.com/biz/pho-ga-hai-van-westmi...           371
# 16  https://www.yelp.com/biz/pho-101-westminster-2...           854
# 17  https://www.yelp.com/biz/pho-318-fountain-vall...            36
# 18  https://www.yelp.com/biz/pho-thanh-westminster...           559
# 19  https://www.yelp.com/biz/pho-v-999-santa-ana?a...             1
#
#                                            categories  rating  \
# 0   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 1   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     5.0
# 2   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 3    [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.5
# 4    [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.5
# 5   [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
# 6   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 7   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 8   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 9    [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.0
# 10   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.0
# 11   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.5
# 12  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     5.0
# 13  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 14   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.0
# 15  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.5
# 16   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.5
# 17  [{'alias': 'noodles', 'title': 'Noodles'}, {'a...     4.5
# 18   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     3.0
# 19   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     1.0
#
#                                           coordinates  \
# 0    {'latitude': 33.752461, 'longitude': -117.95576}
# 1   {'latitude': 33.744605, 'longitude': -117.919228}
# 2   {'latitude': 33.773819, 'longitude': -117.918706}
# 3   {'latitude': 33.773181, 'longitude': -117.956079}
# 4   {'latitude': 33.773975, 'longitude': -117.997094}
# 5   {'latitude': 33.753255, 'longitude': -117.954161}
# 6   {'latitude': 33.7457405317976, 'longitude': -1...
# 7   {'latitude': 33.7736410518458, 'longitude': -1...
# 8     {'latitude': 33.79322, 'longitude': -117.91565}
# 9   {'latitude': 33.77753161636378, 'longitude': -...
# 10    {'latitude': 33.74462, 'longitude': -117.91769}
# 11  {'latitude': 33.7603975554134, 'longitude': -1...
# 12  {'latitude': 33.75946615459932, 'longitude': -...
# 13  {'latitude': 33.78160053038838, 'longitude': -...
# 14  {'latitude': 33.7591026, 'longitude': -117.951...
# 15  {'latitude': 33.7582520286557, 'longitude': -1...
# 16  {'latitude': 33.7304718465855, 'longitude': -1...
# 17  {'latitude': 33.727108, 'longitude': -117.920286}
# 18   {'latitude': 33.74519, 'longitude': -117.961072}
# 19  {'latitude': 33.744809, 'longitude': -117.916544}
#
#                                   transactions price  \
# 0                                   [delivery]    $$
# 1                     [restaurant_reservation]    $$
# 2                                   [delivery]    $$
# 3                                           []    $$
# 4   [delivery, pickup, restaurant_reservation]    $$
# 5   [delivery, pickup, restaurant_reservation]    $$
# 6                                   [delivery]    $$
# 7                                   [delivery]    $$
# 8                           [pickup, delivery]    $$
# 9                                   [delivery]    $$
# 10                                          []    $$
# 11                                          []   NaN
# 12                                          []    $$
# 13                          [pickup, delivery]    $$
# 14                                  [delivery]    $$
# 15                                  [delivery]    $$
# 16                                  [delivery]    $$
# 17                                          []   NaN
# 18                                  [delivery]    $$
# 19                                          []   NaN
#
#                                              location         phone  \
# 0   {'address1': '9941 Hazard Ave', 'address2': ''...  +17145312490
# 1   {'address1': '111 S Harbor Blvd', 'address2': ...  +16572319378
# 2   {'address1': '13032 Harbor Blvd', 'address2': ...  +17145390186
# 3   {'address1': '10130 Garden Grove Blvd', 'addre...  +17145915265
# 4   {'address1': '7725 Garden Grove Blvd', 'addres...  +17146224896
# 5   {'address1': '14376 Brookhurst St', 'address2'...  +16579668984
# 6   {'address1': '14932 Bushard St', 'address2': '...  +17147338822
# 7   {'address1': '9240 Garden Grove Blvd', 'addres...  +17145379000
# 8   {'address1': '2191 S Harbor Blvd', 'address2':...  +17147507500
# 9   {'address1': '12801 Harbor Blvd', 'address2': ...  +17145900188
# 10  {'address1': '3610 W 1st St', 'address2': 'Ste...  +17145316634
# 11  {'address1': '13916 Brookhurst St', 'address2'...  +17146361300
# 12  {'address1': '10742 Westminster Ave', 'address...  +17145838331
# 13  {'address1': '445 S Main St', 'address2': 'Ste...  +17147715410
# 14  {'address1': '10212 Westminster Ave', 'address...  +17145959917
# 15  {'address1': '14072 Magnolia St', 'address2': ...  +16574009140
# 16  {'address1': '8031 Edinger Ave', 'address2': N...  +17143753330
# 17  {'address1': '16285 Harbor Blvd', 'address2': ...  +17146983185
# 18  {'address1': '9625 Bolsa Ave', 'address2': Non...  +17148399882
# 19  {'address1': '3522 W 1st St', 'address2': None...
#
#      display_phone     distance
# 0   (714) 531-2490  4323.481691
# 1   (657) 231-9378  1147.697316
# 2   (714) 539-0186  2732.269818
# 3   (714) 591-5265  5018.476634
# 4   (714) 622-4896  8549.683763
# 5   (657) 966-8984  4189.114221
# 6   (714) 733-8822  5048.432469
# 7   (714) 537-9000  6286.962121
# 8   (714) 750-7500  4770.843129
# 9   (714) 590-0188  3070.733827
# 10  (714) 531-6634  1037.551953
# 11  (714) 636-1300  4361.829400
# 12  (714) 583-8331  3178.220862
# 13  (714) 771-5410  5192.799597
# 14  (714) 595-9917  4027.729310
# 15  (657) 400-9140  5842.121258
# 16  (714) 375-3330  7658.379870
# 17  (714) 698-3185  2856.969156
# 18  (714) 839-9882  4847.227166
# 19                   945.072378

# %%
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 30

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# # Open the Final JSON file with pandas

# %%
df = pd.read_json(JSON_FILE)
df.head()
# Out:
#                        id                        alias             name  \
# 0  I8aR6AojaY3w4bfiL5zacg    monstar-kitchen-santa-ana  Monstar Kitchen
# 1  FjzHELOnbk0oFBCEluBs7g    pho-nam-dinh-garden-grove     Pho Nam Dinh
# 2  dItF3E6UqrS_MjmiFaaLfQ      pho-flavor-garden-grove       Pho Flavor
# 3  TT0Y5sxPE2R5l0Pv_VxbNQ       pho-redbo-garden-grove        Pho Redbo
# 4  jGlHGLneaPZ3vS5l0nRRXA  pho-kuroushi-garden-grove-2     Pho Kuroushi
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/K5m1f8...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/WBrzet...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/Y8P-FH...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/BE9BsO...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/x6gPI4...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/monstar-kitchen-santa...            37
# 1  https://www.yelp.com/biz/pho-nam-dinh-garden-g...           556
# 2  https://www.yelp.com/biz/pho-flavor-garden-gro...           334
# 3  https://www.yelp.com/biz/pho-redbo-garden-grov...           933
# 4  https://www.yelp.com/biz/pho-kuroushi-garden-g...           137
#
#                                           categories  rating  \
# 0  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     5.0
# 1  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 2   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.5
# 3   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.5
# 4  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
#
#                                          coordinates  \
# 0  {'latitude': 33.744605, 'longitude': -117.919228}
# 1  {'latitude': 33.773819, 'longitude': -117.918706}
# 2  {'latitude': 33.773181, 'longitude': -117.956079}
# 3  {'latitude': 33.773975, 'longitude': -117.997094}
# 4  {'latitude': 33.753255, 'longitude': -117.954161}
#
#                                  transactions price  \
# 0                    [restaurant_reservation]    $$
# 1                                  [delivery]    $$
# 2                                          []    $$
# 3  [restaurant_reservation, pickup, delivery]    $$
# 4  [restaurant_reservation, pickup, delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '111 S Harbor Blvd', 'address2': ...  +16572319378
# 1  {'address1': '13032 Harbor Blvd', 'address2': ...  +17145390186
# 2  {'address1': '10130 Garden Grove Blvd', 'addre...  +17145915265
# 3  {'address1': '7725 Garden Grove Blvd', 'addres...  +17146224896
# 4  {'address1': '14376 Brookhurst St', 'address2'...  +16579668984
#
#     display_phone     distance
# 0  (657) 231-9378  1147.697316
# 1  (714) 539-0186  2732.269818
# 2  (714) 591-5265  5018.476634
# 3  (714) 622-4896  8549.683763
# 4  (657) 966-8984  4189.114221

# %%
df.tail()
# Out:
#                          id                           alias  \
# 581  YJoIaX8sd6fwYGSG4x4ZQQ  85-c-bakery-cafe-irvine-irvine
# 582  5ECCio6ej_mN12QZ5mOdpg   waikiki-hawaiian-grill-orange
# 583  PUeGfzWMVFtbJXLYXOA4xA    stater-bros-markets-tustin-3
# 584  5ECCio6ej_mN12QZ5mOdpg   waikiki-hawaiian-grill-orange
# 585  PUeGfzWMVFtbJXLYXOA4xA    stater-bros-markets-tustin-3
#
#                         name  \
# 581  85°C Bakery Cafe-Irvine
# 582   Waikiki Hawaiian Grill
# 583     Stater Bros. Markets
# 584   Waikiki Hawaiian Grill
# 585     Stater Bros. Markets
#
#                                              image_url  is_closed  \
# 581  https://s3-media2.fl.yelpcdn.com/bphoto/ETzNYO...      False
# 582  https://s3-media2.fl.yelpcdn.com/bphoto/qrl0LH...      False
# 583  https://s3-media1.fl.yelpcdn.com/bphoto/fMjft0...      False
# 584  https://s3-media2.fl.yelpcdn.com/bphoto/qrl0LH...      False
# 585  https://s3-media1.fl.yelpcdn.com/bphoto/fMjft0...      False
#
#                                                    url  review_count  \
# 581  https://www.yelp.com/biz/85-c-bakery-cafe-irvi...          6127
# 582  https://www.yelp.com/biz/waikiki-hawaiian-gril...           214
# 583  https://www.yelp.com/biz/stater-bros-markets-t...           116
# 584  https://www.yelp.com/biz/waikiki-hawaiian-gril...           214
# 585  https://www.yelp.com/biz/stater-bros-markets-t...           116
#
#                                             categories  rating  \
# 581  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 582  [{'alias': 'hawaiian', 'title': 'Hawaiian'}, {...     3.0
# 583  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...     3.0
# 584  [{'alias': 'hawaiian', 'title': 'Hawaiian'}, {...     3.0
# 585  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...     3.0
#
#                                            coordinates transactions price  \
# 581  {'latitude': 33.688074465796134, 'longitude': ...   [delivery]     $
# 582    {'latitude': 33.82258, 'longitude': -117.83641}   [delivery]     $
# 583  {'latitude': 33.7323158, 'longitude': -117.816...           []     $
# 584    {'latitude': 33.82258, 'longitude': -117.83641}   [delivery]     $
# 585  {'latitude': 33.7323158, 'longitude': -117.816...           []     $
#
#                                               location         phone  \
# 581  {'address1': '2700 Alton Pkwy', 'address2': 'S...  +19495538585
# 582  {'address1': '2094 N Tustin St', 'address2': '...  +17146856833
# 583  {'address1': '14171 Red Hill Ave', 'address2':...  +17145441812
# 584  {'address1': '2094 N Tustin St', 'address2': '...  +17146856833
# 585  {'address1': '14171 Red Hill Ave', 'address2':...  +17145441812
#
#       display_phone      distance
# 581  (949) 553-8585   9819.381635
# 582  (714) 685-6833  10443.788367
# 583  (714) 544-1812   8763.706867
# 584  (714) 685-6833  10443.788367
# 585  (714) 544-1812   8763.706867

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             586 non-null    object
#  1   alias          586 non-null    object
#  2   name           586 non-null    object
#  3   image_url      586 non-null    object
#  4   is_closed      586 non-null    bool
#  5   url            586 non-null    object
#  6   review_count   586 non-null    int64
#  7   categories     586 non-null    object
#  8   rating         586 non-null    float64
#  9   coordinates    586 non-null    object
#  10  transactions   586 non-null    object
#  11  price          538 non-null    object
#  12  location       586 non-null    object
#  13  phone          586 non-null    object
#  14  display_phone  586 non-null    object
#  15  distance       586 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 69.4+ KB

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Santa Ana-pho.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)
