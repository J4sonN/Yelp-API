# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# # Load Credentials and Create Yelp API objects

# %%
with open(r"C:\Users\black\.secret\yelp_api.json") as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
yelp =  YelpAPI(login['api-key'], timeout_s = 5.0)

# %%
location = 'Santa Ana, CA 92703'
term = 'pho'

# %%
location.split(',')[0]
# Out:
# 'Santa Ana'

# %%
## Specify fodler for saving data
Folder = 'Data/'

os.makedirs(Folder, exist_ok = True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = Folder+f"{location.split(',')[0]}-{term}.json"

# %% [markdown]
# # Check if Json file exists and create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. saving empty list to file")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
        json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Santa Ana-pho.json already exists.

# %%
results = yelp.search_query(term = term, location = location)

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                    alias  \
# 0   svgFm8Ybzq9D8vPPhWE38A           pho-79-restaurant-garden-grove
# 1   I8aR6AojaY3w4bfiL5zacg                monstar-kitchen-santa-ana
# 2   m-holIZGAgiPB-TvKwv47Q               pho-ga-hai-van-westminster
# 3   OHz3pjJ0IvI65_k1Zzu9kA      soup-shop-euclid-st-ball-rd-anaheim
# 4   FjzHELOnbk0oFBCEluBs7g                pho-nam-dinh-garden-grove
# 5   dItF3E6UqrS_MjmiFaaLfQ                  pho-flavor-garden-grove
# 6   o-54PxRLT_teg18hwEmACg  99999-restaurant-phở-út-nô-garden-grove
# 7   taFNrl6cmfUXybwRrugAjg                    pho-good-garden-grove
# 8   TT0Y5sxPE2R5l0Pv_VxbNQ                   pho-redbo-garden-grove
# 9   jGlHGLneaPZ3vS5l0nRRXA              pho-kuroushi-garden-grove-2
# 10  fAptoiXJxRK7KqaNsBAKTg                   phoholic-westminster-2
# 11  t1wUKwUTUGaQzoAlxzVFGw                         mr-pho-anaheim-3
# 12  7_lDdYuloowE2Jlav8PRnQ                      pho-45-garden-grove
# 13  WqOU7uoczSj_9EFrC7I76A                     pho-54-westminster-2
# 14  akDEGLtmQJbTEdGumTtLQg                      pho-lu-garden-grove
# 15  L9hK2pkuA-Pykty3cBw_Jg                    saigon-9-garden-grove
# 16  pRRjdTSeclWX7VEeN277vQ     pho-tau-bay-ltt-restaurant-santa-ana
# 17  ej4KJDPJ91PkBIcR_82Hfg                 pho-lab-huntington-beach
# 18  vK-jtjE3cvO89juM-bVeHA    quán-bún-cô-giáo-thảo-garden-grove-12
# 19  EjuethqTHCA76eW43u7hpQ                   nguyens-kitchen-orange
#
#                                name  \
# 0                 Pho 79 Restaurant
# 1                   Monstar Kitchen
# 2                    Pho Ga Hai Van
# 3   Soup Shop - Euclid St./Ball Rd.
# 4                      Pho Nam Dinh
# 5                        Pho Flavor
# 6      99999 Restaurant - Phở Út Nô
# 7                          Pho Good
# 8                         Pho Redbo
# 9                      Pho Kuroushi
# 10                         PhoHolic
# 11                           Mr Pho
# 12                           Pho 45
# 13                           Pho 54
# 14                           Pho Lu
# 15                         Saigon 9
# 16       Pho Tau Bay Ltt Restaurant
# 17                          Pho Lab
# 18           Quán Bún Cô Giáo Thảo
# 19                 Nguyen's Kitchen
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/y_SL4P...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/K5m1f8...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/0VXKK1...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/Bcw6b0...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/WBrzet...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/Y8P-FH...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/tFP_Pd...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/8CAD3I...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/BE9BsO...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/x6gPI4...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/dsdPDz...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/4c8mea...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/aYlDYm...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/NHN_vS...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/hJ1pom...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/tklMDC...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/YJIvNX...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/OxC08e...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/8wKZI2...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/lBs0Iv...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/pho-79-restaurant-gar...          3094
# 1   https://www.yelp.com/biz/monstar-kitchen-santa...            37
# 2   https://www.yelp.com/biz/pho-ga-hai-van-westmi...           371
# 3   https://www.yelp.com/biz/soup-shop-euclid-st-b...           274
# 4   https://www.yelp.com/biz/pho-nam-dinh-garden-g...           556
# 5   https://www.yelp.com/biz/pho-flavor-garden-gro...           334
# 6   https://www.yelp.com/biz/99999-restaurant-ph%E...            57
# 7   https://www.yelp.com/biz/pho-good-garden-grove...           272
# 8   https://www.yelp.com/biz/pho-redbo-garden-grov...           933
# 9   https://www.yelp.com/biz/pho-kuroushi-garden-g...           137
# 10  https://www.yelp.com/biz/phoholic-westminster-...          1443
# 11  https://www.yelp.com/biz/mr-pho-anaheim-3?adju...           718
# 12  https://www.yelp.com/biz/pho-45-garden-grove?a...          1852
# 13  https://www.yelp.com/biz/pho-54-westminster-2?...           917
# 14  https://www.yelp.com/biz/pho-lu-garden-grove?a...          1713
# 15  https://www.yelp.com/biz/saigon-9-garden-grove...           405
# 16  https://www.yelp.com/biz/pho-tau-bay-ltt-resta...           328
# 17  https://www.yelp.com/biz/pho-lab-huntington-be...           340
# 18  https://www.yelp.com/biz/qu%C3%A1n-b%C3%BAn-c%...           584
# 19  https://www.yelp.com/biz/nguyens-kitchen-orang...          2439
#
#                                            categories  rating  \
# 0   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 1   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     5.0
# 2   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.5
# 3   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.5
# 4   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 5    [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.5
# 6   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     5.0
# 7   [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 8    [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.5
# 9   [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
# 10  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 11  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 12  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 13  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     3.5
# 14  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     3.5
# 15   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.0
# 16   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.0
# 17  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     5.0
# 18   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.0
# 19  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
#
#                                           coordinates  \
# 0    {'latitude': 33.752461, 'longitude': -117.95576}
# 1   {'latitude': 33.744605, 'longitude': -117.919228}
# 2   {'latitude': 33.7582520286557, 'longitude': -1...
# 3   {'latitude': 33.818802, 'longitude': -117.9412...
# 4   {'latitude': 33.773819, 'longitude': -117.918706}
# 5   {'latitude': 33.773181, 'longitude': -117.956079}
# 6   {'latitude': 33.75946615459932, 'longitude': -...
# 7   {'latitude': 33.7883651, 'longitude': -117.962...
# 8   {'latitude': 33.773975, 'longitude': -117.997094}
# 9   {'latitude': 33.753255, 'longitude': -117.954161}
# 10  {'latitude': 33.7457405317976, 'longitude': -1...
# 11    {'latitude': 33.79322, 'longitude': -117.91565}
# 12  {'latitude': 33.7736410518458, 'longitude': -1...
# 13   {'latitude': 33.73859, 'longitude': -117.954409}
# 14  {'latitude': 33.7596326, 'longitude': -117.952...
# 15  {'latitude': 33.77753161636378, 'longitude': -...
# 16    {'latitude': 33.74462, 'longitude': -117.91769}
# 17   {'latitude': 33.700928, 'longitude': -117.98758}
# 18  {'latitude': 33.7591026, 'longitude': -117.951...
# 19  {'latitude': 33.78160053038838, 'longitude': -...
#
#                                   transactions price  \
# 0                                   [delivery]    $$
# 1                     [restaurant_reservation]    $$
# 2                                   [delivery]    $$
# 3                           [delivery, pickup]    $$
# 4                                   [delivery]    $$
# 5                                           []    $$
# 6                                           []    $$
# 7                           [delivery, pickup]    $$
# 8   [restaurant_reservation, delivery, pickup]    $$
# 9   [restaurant_reservation, delivery, pickup]    $$
# 10                                  [delivery]    $$
# 11                          [delivery, pickup]    $$
# 12                                  [delivery]    $$
# 13                                          []    $$
# 14                                  [delivery]    $$
# 15                                  [delivery]    $$
# 16                                          []    $$
# 17                          [delivery, pickup]    $$
# 18                                  [delivery]    $$
# 19                          [delivery, pickup]    $$
#
#                                              location         phone  \
# 0   {'address1': '9941 Hazard Ave', 'address2': ''...  +17145312490
# 1   {'address1': '111 S Harbor Blvd', 'address2': ...  +16572319378
# 2   {'address1': '14072 Magnolia St', 'address2': ...  +16574009140
# 3   {'address1': '920 S Euclid St', 'address2': No...  +17148294271
# 4   {'address1': '13032 Harbor Blvd', 'address2': ...  +17145390186
# 5   {'address1': '10130 Garden Grove Blvd', 'addre...  +17145915265
# 6   {'address1': '10742 Westminster Ave', 'address...  +17145838331
# 7   {'address1': '9752 Chapman Ave', 'address2': '...  +17145343040
# 8   {'address1': '7725 Garden Grove Blvd', 'addres...  +17146224896
# 9   {'address1': '14376 Brookhurst St', 'address2'...  +16579668984
# 10  {'address1': '14932 Bushard St', 'address2': '...  +17147338822
# 11  {'address1': '2191 S Harbor Blvd', 'address2':...  +17147507500
# 12  {'address1': '9240 Garden Grove Blvd', 'addres...  +17145379000
# 13  {'address1': '15420 Brookhurst St', 'address2'...  +17148399096
# 14  {'address1': '10141 Westminster Ave', 'address...  +17145397979
# 15  {'address1': '12801 Harbor Blvd', 'address2': ...  +17145900188
# 16  {'address1': '3610 W 1st St', 'address2': 'Ste...  +17145316634
# 17  {'address1': '8112 Talbert Ave', 'address2': '...  +17145943879
# 18  {'address1': '10212 Westminster Ave', 'address...  +17145959917
# 19  {'address1': '445 S Main St', 'address2': 'Ste...  +17147715410
#
#      display_phone     distance
# 0   (714) 531-2490  4323.481691
# 1   (657) 231-9378  1147.697316
# 2   (657) 400-9140  5842.121258
# 3   (714) 829-4271  8153.146652
# 4   (714) 539-0186  2732.269818
# 5   (714) 591-5265  5018.476634
# 6   (714) 583-8331  3178.220862
# 7   (714) 534-3040  6493.681877
# 8   (714) 622-4896  8549.683763
# 9   (657) 966-8984  4189.114221
# 10  (714) 733-8822  5048.432469
# 11  (714) 750-7500  4770.843129
# 12  (714) 537-9000  6286.962121
# 13  (714) 839-9096  4401.266574
# 14  (714) 539-7979  4163.749193
# 15  (714) 590-0188  3070.733827
# 16  (714) 531-6634  1037.551953
# 17  (714) 594-3879  9117.817072
# 18  (714) 595-9917  4027.729310
# 19  (714) 771-5410  5192.799597

# %%
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 30

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# # Open the Final JSON file with pandas

# %%
df = pd.read_json(JSON_FILE)
df.head()
# Out:
#                        id                        alias             name  \
# 0  I8aR6AojaY3w4bfiL5zacg    monstar-kitchen-santa-ana  Monstar Kitchen
# 1  FjzHELOnbk0oFBCEluBs7g    pho-nam-dinh-garden-grove     Pho Nam Dinh
# 2  dItF3E6UqrS_MjmiFaaLfQ      pho-flavor-garden-grove       Pho Flavor
# 3  TT0Y5sxPE2R5l0Pv_VxbNQ       pho-redbo-garden-grove        Pho Redbo
# 4  jGlHGLneaPZ3vS5l0nRRXA  pho-kuroushi-garden-grove-2     Pho Kuroushi
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/K5m1f8...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/WBrzet...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/Y8P-FH...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/BE9BsO...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/x6gPI4...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/monstar-kitchen-santa...            37
# 1  https://www.yelp.com/biz/pho-nam-dinh-garden-g...           556
# 2  https://www.yelp.com/biz/pho-flavor-garden-gro...           334
# 3  https://www.yelp.com/biz/pho-redbo-garden-grov...           933
# 4  https://www.yelp.com/biz/pho-kuroushi-garden-g...           137
#
#                                           categories  rating  \
# 0  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     5.0
# 1  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.0
# 2   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.5
# 3   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.5
# 4  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
#
#                                          coordinates  \
# 0  {'latitude': 33.744605, 'longitude': -117.919228}
# 1  {'latitude': 33.773819, 'longitude': -117.918706}
# 2  {'latitude': 33.773181, 'longitude': -117.956079}
# 3  {'latitude': 33.773975, 'longitude': -117.997094}
# 4  {'latitude': 33.753255, 'longitude': -117.954161}
#
#                                  transactions price  \
# 0                    [restaurant_reservation]    $$
# 1                                  [delivery]    $$
# 2                                          []    $$
# 3  [restaurant_reservation, pickup, delivery]    $$
# 4  [restaurant_reservation, pickup, delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '111 S Harbor Blvd', 'address2': ...  +16572319378
# 1  {'address1': '13032 Harbor Blvd', 'address2': ...  +17145390186
# 2  {'address1': '10130 Garden Grove Blvd', 'addre...  +17145915265
# 3  {'address1': '7725 Garden Grove Blvd', 'addres...  +17146224896
# 4  {'address1': '14376 Brookhurst St', 'address2'...  +16579668984
#
#     display_phone     distance
# 0  (657) 231-9378  1147.697316
# 1  (714) 539-0186  2732.269818
# 2  (714) 591-5265  5018.476634
# 3  (714) 622-4896  8549.683763
# 4  (657) 966-8984  4189.114221

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Santa Ana-pho.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)
